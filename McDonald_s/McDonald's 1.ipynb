# %%
#jsmjsm

# %% [markdown]
# ##                     <c>Hello Everyone, Welcome to McDonald's dataset analysis</c>
# ## Part 1: Data Visulaization
# ![mcdonalds-sultkrumpli-cosmopolitan1415x275.png](attachment:mcdonalds-sultkrumpli-cosmopolitan1415x275.png)

# %% [markdown]
# ### Importing Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
data= pd.read_csv("McD menu1.csv")
data.head(5)
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
datac= data.copy()

# %% [markdown]
# ### Describing and exploring data

# %%
data.shape
# Out:
# (260, 24)

# %%
data.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
data.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
x1= data.drop(data.iloc[:,[0,1,2]],axis=1)

# %%
x1.head()
# Out:
#    Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 0       300                120       13.0                         20
# 1       250                 70        8.0                         12
# 2       370                200       23.0                         35
# 3       450                250       28.0                         43
# 4       400                210       23.0                         35
#
#    Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  Cholesterol  \
# 0            5.0                             25        0.0          260
# 1            3.0                             15        0.0           25
# 2            8.0                             42        0.0           45
# 3           10.0                             52        0.0          285
# 4            8.0                             42        0.0           50
#
#    Cholesterol (% Daily Value)  Sodium  ...  Carbohydrates  \
# ...

# %% [markdown]
# ### Figure out correlation

# %%
# Correlation Plot
from matplotlib import cm as cm

import matplotlib as mpl
# %pylab inline
label_size = 18
mpl.rcParams['xtick.labelsize'] = label_size
mpl.rcParams['ytick.labelsize'] = label_size

sns.set_style("whitegrid")
mask = np.zeros_like(x1.corr(), dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize = (22,18))

cmap = sns.diverging_palette(10,220, as_cmap = True)  #10,133

#Draw
sns.heatmap(x1.corr(), mask = mask, vmax = 1, vmin = -.45, center = 0,cmap=cmap,
           annot = True, square = True, linewidth = .5, cbar_kws = {'shrink':.5}, fmt= '.2f')
plt.text(8, 1, 'Courtesy: https://seaborn.pydata.org/examples/many_pairwise_correlations.html', fontsize=16,alpha=0.2)
plt.title("Nutrition Value Correlation", loc = 'center', size = 32, color = '#34495E')
#plt.savefig('Correlation Matrix'+'.png', bbox_inches = 'tight')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Text(0.5, 1.0, 'Nutrition Value Correlation')

# %%
sns.pairplot(data[['Category','Calories', 'Total Fat (% Daily Value)','Carbohydrates (% Daily Value)', 'Dietary Fiber (% Daily Value)']],hue='Category')
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Explore Calories

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution Calories")
ax = sns.distplot(data["Calories"], color ='b')
print("Mean of data = ",data.Calories.mean())
print("Median of data = ",data.Calories.median())
# Out:
# Mean of data =  368.2692307692308
# Median of data =  340.0

# %%
# Histogram
# bins = number of bar in figure
data.Calories.plot(kind = 'hist',bins = 70,figsize = (12,12))
plt.show()

# %%
# Line Plot
# color = color, label = label, linewidth = width of line, alpha = opacity, grid = grid, linestyle = sytle of line
data.Calories.plot(kind = 'line', color = 'g',label = 'Calories',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data['Calories from Fat'].plot(color = 'r',label = 'Calories from Fat',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('x axis')              # label = name of label
plt.ylabel('y axis')
plt.title('Line Plot')            # title = title of plot
plt.show()

# %%
s=max(data['Calories'])
data[(data.Calories ==s)]
#hmm,look at this cause of high sugar in the blood!McFlurry!
# Out:
#           Category                          Item     Serving Size  Calories  \
# 82  Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)      1880
#
#     Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 82               1060      118.0                        182           20.0
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 82                            101        1.0  ...            118
#
#     Carbohydrates (% Daily Value)  Dietary Fiber  \
# 82                             39              6
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 82                             24       1       87                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 82                         15                        8                    25
#
# [1 rows x 24 columns]

# %% [markdown]
# ### Explore Fats

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution Total Fats")
ax = sns.distplot(data["Total Fat"], color ='forestgreen')
print("Mean of data = ",data.Calories.mean())
print("Median of data = ",data.Calories.median())
# Out:
# Mean of data =  368.2692307692308
# Median of data =  340.0

# %%
# Line Plot
# color = color, label = label, linewidth = width of line, alpha = opacity, grid = grid, linestyle = sytle of line
data['Total Fat'].plot(kind = 'line', color = 'g',label = 'Fats',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data['Saturated Fat'].plot(color = 'r',label = 'Saturated Fat',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('x axis')              # label = name of label
plt.ylabel('y axis')
plt.title('Line Plot')            # title = title of plot
plt.show()

# %%
s=max(data['Total Fat'])
data[(data['Total Fat'] ==s)]
#hmm,look at this cause of high sugar in the blood!McFlurry!
# Out:
#           Category                          Item     Serving Size  Calories  \
# 82  Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)      1880
#
#     Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 82               1060      118.0                        182           20.0
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 82                            101        1.0  ...            118
#
#     Carbohydrates (% Daily Value)  Dietary Fiber  \
# 82                             39              6
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 82                             24       1       87                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 82                         15                        8                    25
#
# [1 rows x 24 columns]

# %% [markdown]
# ### Explore Proteins

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution Proteins")
ax = sns.distplot(data["Protein"], color ='deeppink')
print("Mean of data = ",data.Calories.mean())
print("Median of data = ",data.Calories.median())
# Out:
# Mean of data =  368.2692307692308
# Median of data =  340.0

# %%
# Line Plot
# color = color, label = label, linewidth = width of line, alpha = opacity, grid = grid, linestyle = sytle of line
data['Protein'].plot(kind = 'line', color = 'g',label = 'Proteins',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
#data['Saturated Fat'].plot(color = 'r',label = 'Saturated Fat',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('x axis')              # label = name of label
plt.ylabel('y axis')
plt.title('Line Plot')            # title = title of plot
plt.show()

# %%
s=max(data['Protein'])
data[(data['Protein'] ==s)]
#hmm,look at this cause of high sugar in the blood!McFlurry!
# Out:
#           Category                          Item     Serving Size  Calories  \
# 82  Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)      1880
#
#     Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 82               1060      118.0                        182           20.0
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 82                            101        1.0  ...            118
#
#     Carbohydrates (% Daily Value)  Dietary Fiber  \
# 82                             39              6
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 82                             24       1       87                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 82                         15                        8                    25
#
# [1 rows x 24 columns]

# %% [markdown]
# ### Exploring other nutrients like sugar and chloestrol

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt
plt.figure(figsize=(20, 6),)
sns.barplot('Category', 'Calories', data=data);

# %%
print("Maximum and minimum Total_Fat is ",data['Total Fat'].max(),"and ",data['Total Fat'].min())
print("Maximum and minimum Calories is ",data['Calories'].max(),"and ",data['Calories'].min())
print("Maximum and minimum Carbohydrates is ",data['Carbohydrates'].max(),"and ",data['Carbohydrates'].min())
print("Maximum and minimum Sugars is ",data['Sugars'].max(),"and ",data['Sugars'].min())
print("Maximum and minimum Proteins is ",data['Protein'].max(),"and ",data['Protein'].min())
# Out:
# Maximum and minimum Total_Fat is  118.0 and  0.0
# Maximum and minimum Calories is  1880 and  0
# Maximum and minimum Carbohydrates is  141 and  0
# Maximum and minimum Sugars is  128 and  0
# Maximum and minimum Proteins is  87 and  0

# %%
s=max(data['Sugars'])
data[(data.Sugars ==s)]
#hmm,look at this cause of high sugar in the blood!McFlurry!
# Out:
#                Category                                  Item  \
# 253  Smoothies & Shakes  McFlurry with M&M’s Candies (Medium)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 253  16.2 oz (460 g)       930                290       33.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 253                         50           20.0                            102
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 253        1.0  ...            139                             46
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 253              2                              7     128       20
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 253                         25                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 253                       70                    10
#
# [1 rows x 24 columns]

# %%
x = max(data['Cholesterol'])
data[(data.Cholesterol ==x)]
#the most dangerous for your heart breakfasts.It can be your last ...Cholesterol is a cause of heart attacks
# Out:
#      Category                                           Item     Serving Size  \
# 31  Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)  14.8 oz (420 g)
# 32  Breakfast    Big Breakfast with Hotcakes (Large Biscuit)  15.3 oz (434 g)
#
#     Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 31      1090                510       56.0                         87
# 32      1150                540       60.0                         93
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 31           19.0                             96        0.0  ...
# 32           20.0                            100        0.0  ...
#
#     Carbohydrates  Carbohydrates (% Daily Value)  Dietary Fiber  \
# 31            111                             37              6
# 32            116                             39              7
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# ...

# %%
miktar = ['Trans Fat','Calories', 'Total Fat', 'Cholesterol','Sodium', 'Sugars', 'Carbohydrates']
plt.figure(figsize=(16,5))
for x in miktar:   
    plot = sns.swarmplot(x="Category", y=x, data=data)
    plt.setp(plot.get_xticklabels(), rotation=45)
    plt.title(x)
    plt.figure(figsize=(16,5))
    plt.show()

# %%
sns.barplot(x=data.groupby('Category')['Calories'].mean().index,y=data.groupby('Category')['Calories'].mean().values)
plt.title("total calories of each menu")
plt.ylabel("calories")
plt.xlabel("menu")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(16,5))
sns.boxplot(data= data, x = 'Category',y = 'Dietary Fiber')
plt.tight_layout
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(16,5))
Max_Cal = data.groupby('Category').max().sort_values('Calories',ascending=False)
sns.swarmplot(data =Max_Cal, x= Max_Cal.index,y = 'Calories',hue ='Item',size =10 )
plt.xticks(rotation=45)
plt.tight_layout()

# %%
measures = ['Calories', 'Total Fat', 'Cholesterol','Sodium', 'Sugars', 'Carbohydrates']
plt.xticks(rotation=45)
for m in measures:   
    plot = sns.violinplot(x="Category", y=m, data=data)
    plt.setp(plot.get_xticklabels(), size=7)
    plt.title(m)
    plt.figure(figsize=(16,5))    
    plt.show()

# %%
for m in measures:
    plt.xticks(rotation=45)
    g = sns.factorplot(x="Category", y=m,data=data, kind="swarm",size=5, aspect=2.5,)

# %% [markdown]
# # JSMJSM
